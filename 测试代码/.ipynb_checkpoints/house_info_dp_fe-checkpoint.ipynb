# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.io.json import json_normalize
from pylab import mpl

plt.style.use('ggplot')
mpl.rcParams['font.sans-serif'] = ['SimHei']  #解决seaborn中文字体显示问题
plt.rc('figure', figsize=(10, 10))  #把plt默认的图片size调大一点

path = "../测试数据/data_sample.csv"
data = pd.read_csv(path)
data.head()
# Out:
#                         _id  bathroom_num  bedroom_num bizcircle_name city  \
# 0  5c714363397be4c5251a3ded             2            3             上地   北京
# 1  5c7148e6397be4c5251a583d             1            2            北大地   北京
# 2  5c71321e397be4c5251a0b46             1            1             燕莎   北京
# 3  5c712721397be4c52519fc09             1            1            阜成门   北京
# 4  5c7123bd397be4c52519f7af             1            2            和平里   北京
#
#   dist  distance frame_orientation  hall_num      house_tag  \
# 0   海淀       NaN               南 北         2   精装 集中供暖 双卫生间
# 1   丰台       NaN               南 北         1           集中供暖
# 2   朝阳     788.0                 北         1    近地铁 精装 集中供暖
# 3   西城     886.0                 东         1  近地铁 集中供暖 随时看房
# 4   朝阳     779.0               东 南         1       近地铁 集中供暖
#
#                       house_title   latitude  layout   longitude  \
# 0  整租 · 上地西里二层三居 自住出租 随时入住采光好 无遮挡  40.039000  3室2厅2卫  116.317831
# 1       整租 · 丰台北大地电报局街家具家电齐全南北向两居  39.856662  2室1厅1卫  116.292291
# 2          整租 · 远洋新干线 1室1厅 10500元  39.963231  1室1厅1卫  116.466150
# 3                  南露园 1室1厅 5600元  39.930655  1室1厅1卫  116.348521
# 4            和平里东街15号院 2室1厅 6300元  39.957079  2室1厅1卫  116.431393
#
#                                                m_url rent_area  \
# 0  https://m.lianjia.com/chuzu/bj/zufang/BJ213593...       137
# 1  https://m.lianjia.com/chuzu/bj/zufang/BJ210122...        57
# 2  https://m.lianjia.com/chuzu/bj/zufang/BJ216317...        56
# 3  https://m.lianjia.com/chuzu/bj/zufang/BJ217362...        43
# 4  https://m.lianjia.com/chuzu/bj/zufang/BJ215869...        56
#
#   rent_price_listing rent_price_unit resblock_name type
# 0              15000             元/月          上地西里   整租
# 1               4500             元/月          电报局街   整租
# 2              10500             元/月         远洋新干线   整租
# 3               5600             元/月           南露园   整租
# 4               6300             元/月     和平里东街15号院   整租

# %%
def get_city_zf_loc(city, city_short, col=['longitude', 'latitude', 'dist'], data=data):
    file_name = 'data_' + city_short + '_latlon.csv'
    data_latlon = data.loc[data['city']==city, col].dropna(subset=['latitude', 'longitude'])
    data_latlon['longitude'] = data_latlon['longitude'].astype(str)
    data_latlon['latitude'] = data_latlon['latitude'].astype(str)
    data_latlon['latlon'] = data_latlon['longitude'].str.cat(data_latlon['latitude'], sep=',')
    data_latlon.to_csv(file_name, index=False)
    print(city+'的数据一共有{}条'.format(data_latlon.shape[0]))

# %%
get_city_zf_loc('北京', 'bj', ['longitude','latitude', 'dist'])
get_city_zf_loc('上海', 'sh', ['longitude','latitude', 'dist'])
get_city_zf_loc('广州', 'gz', ['longitude','latitude', 'dist'])
get_city_zf_loc('深圳', 'sz', ['longitude','latitude', 'dist'])
# Out:
# 北京的数据一共有2996条
# 上海的数据一共有2992条
# 广州的数据一共有2987条
# 深圳的数据一共有2994条

# %%
import matplotlib.pyplot as plt
fig = plt.figure(dpi=300)
data.dropna(subset=['latitude', 'longitude'])[data['city']=='北京']['dist'].value_counts(ascending=True).plot.barh()
plt.show()
# Out:
# /Users/QSY/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
fig = plt.figure(dpi=300)
data.dropna(subset=['latitude', 'longitude'])[data['city']=='上海']['dist'].value_counts(ascending=True).plot.barh()
# Out:
# /Users/QSY/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
fig = plt.figure(dpi=300)
data.dropna(subset=['latitude', 'longitude'])[data['city']=='广州']['dist'].value_counts(ascending=True).plot.barh()

# data.dropna(subset=['latitude', 'longitude'])[data['city']=='广州']['dist'].value_counts(ascending=True).plot.bath()
# Out:
# /Users/QSY/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
fig = plt.figure(dpi=300)
data.dropna(subset=['latitude', 'longitude'])[data['city']=='深圳']['dist'].value_counts(ascending=True).plot.barh()

# data.dropna(subset=['latitude', 'longitude'])[data['city']=='深圳']['dist'].value_counts(ascending=True).plot.barh()
# Out:
# /Users/QSY/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 20 columns):
# _id                   12000 non-null object
# bathroom_num          12000 non-null int64
# bedroom_num           12000 non-null int64
# bizcircle_name        11999 non-null object
# city                  12000 non-null object
# dist                  12000 non-null object
# distance              6794 non-null float64
# frame_orientation     11899 non-null object
# hall_num              12000 non-null int64
# house_tag             10124 non-null object
# house_title           12000 non-null object
# latitude              11969 non-null float64
# layout                12000 non-null object
# longitude             11969 non-null float64
# m_url                 12000 non-null object
# rent_area             12000 non-null object
# rent_price_listing    12000 non-null object
# rent_price_unit       12000 non-null object
# resblock_name         10486 non-null object
# type                  12000 non-null object
# dtypes: float64(3), int64(3), object(14)
# memory usage: 1.8+ MB

# %%
def get_aver(data):
    if isinstance(data, str) and '-' in data:
        low, high = data.split('-')
        return (int(low)+int(high))/2
    else:
        return int(data)
data['rent_area'] = data['rent_area'].apply(get_aver)
data['rent_price_listing'] = data['rent_price_listing'].apply(get_aver)

# %%
data.head()
# Out:
#                         _id  bathroom_num  bedroom_num bizcircle_name city  \
# 0  5c714363397be4c5251a3ded             2            3             上地   北京
# 1  5c7148e6397be4c5251a583d             1            2            北大地   北京
# 2  5c71321e397be4c5251a0b46             1            1             燕莎   北京
# 3  5c712721397be4c52519fc09             1            1            阜成门   北京
# 4  5c7123bd397be4c52519f7af             1            2            和平里   北京
#
#   dist  distance frame_orientation  hall_num      house_tag  \
# 0   海淀       NaN               南 北         2   精装 集中供暖 双卫生间
# 1   丰台       NaN               南 北         1           集中供暖
# 2   朝阳     788.0                 北         1    近地铁 精装 集中供暖
# 3   西城     886.0                 东         1  近地铁 集中供暖 随时看房
# 4   朝阳     779.0               东 南         1       近地铁 集中供暖
#
#                       house_title   latitude  layout   longitude  \
# 0  整租 · 上地西里二层三居 自住出租 随时入住采光好 无遮挡  40.039000  3室2厅2卫  116.317831
# 1       整租 · 丰台北大地电报局街家具家电齐全南北向两居  39.856662  2室1厅1卫  116.292291
# 2          整租 · 远洋新干线 1室1厅 10500元  39.963231  1室1厅1卫  116.466150
# 3                  南露园 1室1厅 5600元  39.930655  1室1厅1卫  116.348521
# 4            和平里东街15号院 2室1厅 6300元  39.957079  2室1厅1卫  116.431393
#
#                                                m_url  rent_area  \
# 0  https://m.lianjia.com/chuzu/bj/zufang/BJ213593...      137.0
# 1  https://m.lianjia.com/chuzu/bj/zufang/BJ210122...       57.0
# 2  https://m.lianjia.com/chuzu/bj/zufang/BJ216317...       56.0
# 3  https://m.lianjia.com/chuzu/bj/zufang/BJ217362...       43.0
# 4  https://m.lianjia.com/chuzu/bj/zufang/BJ215869...       56.0
#
#    rent_price_listing rent_price_unit resblock_name type
# 0             15000.0             元/月          上地西里   整租
# 1              4500.0             元/月          电报局街   整租
# 2             10500.0             元/月         远洋新干线   整租
# 3              5600.0             元/月           南露园   整租
# 4              6300.0             元/月     和平里东街15号院   整租

# %%
data['aver_price'] = np.round(data['rent_price_listing'] / data['rent_area'], 1)

# %%
g = sns.FacetGrid(data, row='city', aspect=2)
g = g.map(sns.kdeplot, "aver_price")

# %%
def get_city_zf_aver_price(city, city_short, col=['longitude', 'latitude', 'aver_price'], data=data):
    file_name = 'data_' + city_short + '_aver_price.csv'
    data_latlon = data.loc[(data['city']==city)&(data['aver_price']<=250), col].dropna(subset=['latitude', 'longitude'])
    data_latlon['longitude'] = data_latlon['longitude'].astype(str)
    data_latlon['latitude'] = data_latlon['latitude'].astype(str)
    data_latlon['latlon'] = data_latlon['longitude'].str.cat(data_latlon['latitude'], sep=',')
    data_latlon.to_csv(file_name, index=False)
    print(city+'的数据一共有{}条'.format(data_latlon.shape[0]))
get_city_zf_aver_price('北京', 'bj')
get_city_zf_aver_price('上海', 'sh')
get_city_zf_aver_price('广州', 'gz')
get_city_zf_aver_price('深圳', 'sz')
# Out:
# 北京的数据一共有2969条
# 上海的数据一共有2979条
# 广州的数据一共有2976条
# 深圳的数据一共有2931条

# %%
# 各城市租金Top10的商圈
bc_top10 = data.groupby(['city', 'bizcircle_name'])
print(bc_top10)
bc_top10 = bc_top10['aver_price'].mean().nlargest(50).reset_index()['city'].value_counts()

# bc_top10 = data.groupby(['city', 'bizcircle_name'])['aver_price'].mean().nlargest(50).reset_index()['city'].value_counts()
# Out:
# city  bizcircle_name  aver_price
# 上海    七宝              70.8          2
#                       92.3          2
#                       61.4          1
#                       71.4          1
#                       72.0          1
#                       72.2          1
#                       72.5          1
#                       73.8          1
#                       75.8          1
#                       76.5          1
#                       76.9          1
#                       82.0          1
#                       83.3          1
#                       84.0          1
#                       88.9          1
#                       90.2          1
#                       92.6          1
#                       101.8         1
#                       103.6         1
#                       104.0         1
#                       135.0         1
#                       143.2         1
#       万体馆             66.7          1
#                       67.1          1
#                       84.1          1
#                       90.7          1
#                       92.3          1
#                       98.4          1
#                       112.5         1
#                       114.3         1
#                                    ..
# 深圳    龙岗双龙            37.0          1
#                       38.0          1
#                       39.0          1
#                       39.5          1
#                       40.4          1
#                       41.6          1
#                       42.4          1
#                       43.3          1
#                       45.7          1
#                       46.6          1
#                       48.3          1
#                       49.2          1
#                       49.6          1
#                       50.0          1
#                       50.6          1
#                       50.8          1
#                       54.5          1
#                       55.6          1
#                       57.1          1
#                       58.3          1
#                       59.6          1
#                       60.6          1
#                       60.9          1
#                       63.4          1
#                       95.5          1
#       龙岗宝荷            30.0          1
#                       38.2          1
#                       44.9          1
#                       48.1          1
#                       50.0          1
# Name: aver_price, Length: 11262, dtype: int64

# %%
from pyecharts import Bar
bar = Bar("每平米平均租金前50的北上广深商圈数量", width=400)
bar.add("", bc_top10.index, bc_top10.values, is_stack=True,
       xaxis_label_textsize=16, yaxis_label_textsize=16, is_label_show=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="02d28c4620a54912bb75e8fea6eadf1d" style="width:400px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_02d28c4620a54912bb75e8fea6eadf1d = echarts.init(document.getElementById('02d28c4620a54912bb75e8fea6eadf1d'), 'light', {renderer: 'canvas'});
#
# var option_02d28c4620a54912bb75e8fea6eadf1d = {
#     "title": [
#         {
#             "text": "\u6bcf\u5e73\u7c73\u5e73\u5747\u79df\u91d1\u524d50\u7684\u5317\u4e0a\u5e7f\u6df1\u5546\u5708\u6570\u91cf",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 4228170,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 28.0,
#                 12.0,
#                 9.0,
#                 1.0
#             ],
#             "stack": "stack_4228170",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 4228170
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 16
#                 }
#             },
#             "data": [
#                 "\u5317\u4eac",
#                 "\u4e0a\u6d77",
#                 "\u6df1\u5733",
#                 "\u5e7f\u5dde"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 16
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_02d28c4620a54912bb75e8fea6eadf1d.setOption(option_02d28c4620a54912bb75e8fea6eadf1d);
#
#     });
# </script>

# %%
def get_top10_bc(city, data=data):
    top10_bc = data[(data['city']==city)&(data['bizcircle_name']!='')].groupby('bizcircle_name')['aver_price'].mean().nlargest(10)
    bar = Bar(city+"市每平米平均租金Top10的商圈", width=600)
    bar.add("", top10_bc.index, np.round(top10_bc.values, 0), is_stack=True,
       xaxis_label_textsize=16, yaxis_label_textsize=16, xaxis_rotate=30, is_label_show=True)
    return bar

# %%
get_top10_bc('北京')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="cc6c40625288492dae52750ba383e839" style="width:600px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_cc6c40625288492dae52750ba383e839 = echarts.init(document.getElementById('cc6c40625288492dae52750ba383e839'), 'light', {renderer: 'canvas'});
#
# var option_cc6c40625288492dae52750ba383e839 = {
#     "title": [
#         {
#             "text": "\u5317\u4eac\u5e02\u6bcf\u5e73\u7c73\u5e73\u5747\u79df\u91d1Top10\u7684\u5546\u5708",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 5281730,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 240.0,
#                 231.0,
#                 194.0,
#                 190.0,
#                 189.0,
#                 186.0,
#                 185.0,
#                 183.0,
#                 180.0,
#                 172.0
#             ],
#             "stack": "stack_5281730",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5281730
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 30,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 16
#                 }
#             },
#             "data": [
#                 "\u5730\u5b89\u95e8",
#                 "\u4e1c\u56db",
#                 "\u5d07\u6587\u95e8",
#                 "\u4e2d\u5173\u6751",
#                 "\u4e1c\u5927\u6865",
#                 "\u5de5\u4f53",
#                 "CBD",
#                 "\u91d1\u878d\u8857",
#                 "\u4e2d\u592e\u522b\u5885\u533a",
#                 "\u5efa\u56fd\u95e8\u5916"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 16
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_cc6c40625288492dae52750ba383e839.setOption(option_cc6c40625288492dae52750ba383e839);
#
#     });
# </script>

# %%
data.head()
# Out:
#                         _id  bathroom_num  bedroom_num bizcircle_name city  \
# 0  5c714363397be4c5251a3ded             2            3             上地   北京
# 1  5c7148e6397be4c5251a583d             1            2            北大地   北京
# 2  5c71321e397be4c5251a0b46             1            1             燕莎   北京
# 3  5c712721397be4c52519fc09             1            1            阜成门   北京
# 4  5c7123bd397be4c52519f7af             1            2            和平里   北京
#
#   dist  distance frame_orientation  hall_num      house_tag    ...      \
# 0   海淀       NaN               南 北         2   精装 集中供暖 双卫生间    ...
# 1   丰台       NaN               南 北         1           集中供暖    ...
# 2   朝阳     788.0                 北         1    近地铁 精装 集中供暖    ...
# 3   西城     886.0                 东         1  近地铁 集中供暖 随时看房    ...
# 4   朝阳     779.0               东 南         1       近地铁 集中供暖    ...
#
#     latitude  layout   longitude  \
# 0  40.039000  3室2厅2卫  116.317831
# 1  39.856662  2室1厅1卫  116.292291
# 2  39.963231  1室1厅1卫  116.466150
# 3  39.930655  1室1厅1卫  116.348521
# 4  39.957079  2室1厅1卫  116.431393
#
#                                                m_url rent_area  \
# 0  https://m.lianjia.com/chuzu/bj/zufang/BJ213593...     137.0
# 1  https://m.lianjia.com/chuzu/bj/zufang/BJ210122...      57.0
# 2  https://m.lianjia.com/chuzu/bj/zufang/BJ216317...      56.0
# 3  https://m.lianjia.com/chuzu/bj/zufang/BJ217362...      43.0
# 4  https://m.lianjia.com/chuzu/bj/zufang/BJ215869...      56.0
#
#    rent_price_listing  rent_price_unit resblock_name type aver_price
# 0             15000.0              元/月          上地西里   整租      109.5
# 1              4500.0              元/月          电报局街   整租       78.9
# 2             10500.0              元/月         远洋新干线   整租      187.5
# 3              5600.0              元/月           南露园   整租      130.2
# 4              6300.0              元/月     和平里东街15号院   整租      112.5
#
# [5 rows x 21 columns]

# %%
from scipy import stats
def distance_price_relation(city, data=data):
    g = sns.jointplot(x="distance", 
                  y="aver_price", 
                  data=data[(data['city']==city)&
                            (data['aver_price']<=350)].dropna(subset=['distance']), 
                  kind="reg",
                 stat_func=stats.pearsonr)
    g.fig.set_dpi(100)
    g.ax_joint.set_xlabel('最近地铁距离', fontweight='bold')
    g.ax_joint.set_ylabel('每平米租金', fontweight='bold')
    return g

# %%
distance_price_relation('北京')

# %%
bins = [100*i for i in range(13)]
data['bin'] = pd.cut(data.dropna(subset=['distance'])['distance'], bins)

# %%
bin_bj = data[data['city']=='北京'].groupby('bin')['aver_price'].mean()
bin_sh = data[data['city']=='上海'].groupby('bin')['aver_price'].mean()
bin_gz = data[data['city']=='广州'].groupby('bin')['aver_price'].mean()
bin_sz = data[data['city']=='深圳'].groupby('bin')['aver_price'].mean()

# %%
from pyecharts import Line


line = Line("距离地铁远近跟每平米租金均价的关系")
for city, bin_data in {'北京':bin_bj, '上海':bin_sh, '广州':bin_gz, '深圳':bin_sz}.items():
    line.add(city, bin_data.index, bin_data.values,
            legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
             xaxis_rotate=20, yaxis_min=8, legend_top=30)
line
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pyecharts_javascripthon/api.py in default(self, obj)
#     110         try:
# --> 111             return obj.astype(float).tolist()
#     112
#
# AttributeError: 'pandas._libs.interval.Interval' object has no attribute 'astype'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pyecharts_javascripthon/api.py in default(self, obj)
#     114             try:
# --> 115                 return obj.astype(str).tolist()
#     116
#
# AttributeError: 'pandas._libs.interval.Interval' object has no attribute 'astype'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/anaconda3/lib/python3.6/site-packages/pyecharts/base.py in _repr_html_(self)
#     209             env = engine.create_default_environment(constants.DEFAULT_HTML)
#     210             return env.render_chart_to_notebook(
# --> 211                 charts=(self,), config_items=config_items, libraries=libraries
#     212             )
#     213
#
# ~/anaconda3/lib/python3.6/site-packages/pyecharts/engine.py in render_chart_to_notebook(self, template_name, **context)
#     231         """
#     232         tpl = self.get_template(template_name)
# --> 233         return tpl.render(**context)
#     234
#     235
#
# ~/anaconda3/lib/python3.6/site-packages/jinja2/asyncsupport.py in render(self, *args, **kwargs)
#      74     def render(self, *args, **kwargs):
#      75         if not self.environment.is_async:
# ---> 76             return original_render(self, *args, **kwargs)
#      77         loop = asyncio.get_event_loop()
#      78         return loop.run_until_complete(self.render_async(*args, **kwargs))
#
# ~/anaconda3/lib/python3.6/site-packages/jinja2/environment.py in render(self, *args, **kwargs)
#    1006         except Exception:
#    1007             exc_info = sys.exc_info()
# -> 1008         return self.environment.handle_exception(exc_info, True)
#    1009
#    1010     def render_async(self, *args, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/jinja2/environment.py in handle_exception(self, exc_info, rendered, source_hint)
#     778             self.exception_handler(traceback)
#     779         exc_type, exc_value, tb = traceback.standard_exc_info
# --> 780         reraise(exc_type, exc_value, tb)
#     781
#     782     def join_path(self, template, parent):
#
# ~/anaconda3/lib/python3.6/site-packages/jinja2/_compat.py in reraise(tp, value, tb)
#      35     def reraise(tp, value, tb=None):
#      36         if value.__traceback__ is not tb:
# ---> 37             raise value.with_traceback(tb)
#      38         raise value
#      39
#
# ~/anaconda3/lib/python3.6/site-packages/pyecharts/templates/notebook.html in top-level template code()
#      13 <script>
#      14     require([{{ libraries | join(', ') }}], function(echarts) {
# ---> 15         {{ echarts_js_content_wrap(*charts) }}
#      16     });
#      17 </script>
#
# ~/anaconda3/lib/python3.6/site-packages/pyecharts/engine.py in echarts_js_content_wrap(env, *charts)
#     135     Render echarts initial code for a chart.
#     136     """
# --> 137     return Markup(generate_js_content(*charts))
#     138
#     139
#
# ~/anaconda3/lib/python3.6/site-packages/pyecharts/engine.py in generate_js_content(*charts)
#      99             FUNCTION_TRANSLATOR.feed(handler)
#     100
# --> 101         javascript_snippet = TRANSLATOR.translate(chart.options)
#     102         kwargs = dict(
#     103             chart_id=chart.chart_id,
#
# ~/anaconda3/lib/python3.6/site-packages/pyecharts_javascripthon/api.py in translate(self, options)
#     125
#     126     def translate(self, options):
# --> 127         option_snippet = json.dumps(options, indent=4, cls=self.json_encoder)
#     128         function_snippet = FUNCTION_TRANSLATOR.translate()
#     129         option_snippet = FUNCTION_TRANSLATOR.handle_options(option_snippet)
#
# ~/anaconda3/lib/python3.6/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# ~/anaconda3/lib/python3.6/json/encoder.py in encode(self, o)
#     199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
# --> 201             chunks = list(chunks)
#     202         return ''.join(chunks)
#     203
#
# ~/anaconda3/lib/python3.6/json/encoder.py in _iterencode(o, _current_indent_level)
#     428             yield from _iterencode_list(o, _current_indent_level)
#     429         elif isinstance(o, dict):
# --> 430             yield from _iterencode_dict(o, _current_indent_level)
#     431         else:
#     432             if markers is not None:
#
# ~/anaconda3/lib/python3.6/json/encoder.py in _iterencode_dict(dct, _current_indent_level)
#     402                 else:
#     403                     chunks = _iterencode(value, _current_indent_level)
# --> 404                 yield from chunks
#     405         if newline_indent is not None:
#     406             _current_indent_level -= 1
#
# ~/anaconda3/lib/python3.6/json/encoder.py in _iterencode_list(lst, _current_indent_level)
#     323                 else:
#     324                     chunks = _iterencode(value, _current_indent_level)
# --> 325                 yield from chunks
#     326         if newline_indent is not None:
#     327             _current_indent_level -= 1
#
# ~/anaconda3/lib/python3.6/json/encoder.py in _iterencode_dict(dct, _current_indent_level)
#     402                 else:
#     403                     chunks = _iterencode(value, _current_indent_level)
# --> 404                 yield from chunks
#     405         if newline_indent is not None:
#     406             _current_indent_level -= 1
#
# ~/anaconda3/lib/python3.6/json/encoder.py in _iterencode_list(lst, _current_indent_level)
#     323                 else:
#     324                     chunks = _iterencode(value, _current_indent_level)
# --> 325                 yield from chunks
#     326         if newline_indent is not None:
#     327             _current_indent_level -= 1
#
# ~/anaconda3/lib/python3.6/json/encoder.py in _iterencode_list(lst, _current_indent_level)
#     323                 else:
#     324                     chunks = _iterencode(value, _current_indent_level)
# --> 325                 yield from chunks
#     326         if newline_indent is not None:
#     327             _current_indent_level -= 1
#
# ~/anaconda3/lib/python3.6/json/encoder.py in _iterencode(o, _current_indent_level)
#     435                     raise ValueError("Circular reference detected")
#     436                 markers[markerid] = o
# --> 437             o = _default(o)
#     438             yield from _iterencode(o, _current_indent_level)
#     439             if markers is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/pyecharts_javascripthon/api.py in default(self, obj)
#     116
#     117             except Exception:
# --> 118                 return super(DefaultJsonEncoder, self).default(obj)
#     119
#     120
#
# ~/anaconda3/lib/python3.6/json/encoder.py in default(self, o)
#     178         """
#     179         raise TypeError("Object of type '%s' is not JSON serializable" %
# --> 180                         o.__class__.__name__)
#     181
#     182     def encode(self, o):
#
# TypeError: Object of type 'Interval' is not JSON serializable

# %%
def area_price_relation(city, data=data):
    fig = plt.figure(dpi=100)
    g = sns.lineplot(x="rent_area",
                     y="aver_price",
                     data=data[(data['city']==city)&(data['rent_area']<150)],
                     ci=None)
    g.set_xlabel('面积', fontweight='bold')
    g.set_ylabel('每平米均价', fontweight='bold')
    return g

# %%
area_price_relation('北京')

# %%
is_dep = data[(data['city'].isin(['广州','深圳']))&
             (data['is_dep']==1)].groupby('city')['aver_price'].mean()
not_dep = data[(data['city'].isin(['广州','深圳']))&
             (data['is_dep']==0)].groupby('city')['aver_price'].mean()

# %%
bar = Bar("个人房源和公寓的每平米租金差别", width=600)
bar.add("个人房源", not_dep.index, np.round(not_dep.values, 0), 
        legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
        xaxis_rotate=20, yaxis_min=8, legend_top=30, is_label_show=True)
bar.add("公寓", is_dep.index, np.round(is_dep.values, 0),
       legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
        xaxis_rotate=20, yaxis_min=8, legend_top=30, is_label_show=True)
bar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-7835c9a140a9> in <module>()
#       1 bar = Bar("个人房源和公寓的每平米租金差别", width=600)
# ----> 2 bar.add("个人房源", not_dep.index, np.round(not_dep.values, 0),
#       3         legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
#       4         xaxis_rotate=20, yaxis_min=8, legend_top=30, is_label_show=True)
#       5 bar.add("公寓", is_dep.index, np.round(is_dep.values, 0),
#
# NameError: name 'not_dep' is not defined
